# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuuya65/characterRecognition/blob/main/characterRecognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 手書き文字を判定させてみよう

# %% [markdown]
# ## １，「あ」、「い」、「う」、「え」、「お」の手書き画像を作ろう

# %% [markdown]
# 以下のURLにアクセスして、開いたページにある「canvas」の中で文字を書いてください。
#
# http://fontjudge.html.xdomain.jp/
#
# 文字を書いたら、「**完了**」をクリックして画像を保存。
#
# 　　　↓↓↓
#
# **エクスプローラー**を開いて、**ダウンロード**の中にファイル名「**canvas**」の画像があれば保存成功です。

# %% [markdown]
# ## ２，手書き画像を Google ドライブにアップロードしよう
#
# 以下のコードを実行して、「**canvas**」画像を **Google ドライブ**にアップロードしてください。

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))

# %% [markdown]
# ## ３，ドライブをマウントしよう
#
# ![untitle.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## ４，画像が正しく読み込めているのかチェックしよう

# %%
from PIL import Image

img = Image.open("/content/canvas.png")

img

# %% [markdown]
# ## ５，手書き文字を判定させよう

# %%
import sys
sys.path.append("/content/drive/MyDrive/data/python")
import mymodule

answer_array = []
path = "/content/canvas.png"

mymodule.createimg(path)

answer_array = mymodule.judge(path)
